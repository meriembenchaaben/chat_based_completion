# %%
from pathlib import Path
import re
import datetime

# ===== Experiment setup =====
MODEL = "llama3.3-70b"
TEMPERATURE = 0
CONFIG_NAME = "C-Min"

scenario_name = "Aircraft maintenance routing system"


def slugify(s: str) -> str:
    s = s.strip().lower()
    s = re.sub(r"[^a-z0-9]+", "_", s)
    return re.sub(r"_+", "_", s).strip("_")

# ===== Create log file =====
logs_dir = Path("logs")
logs_dir.mkdir(exist_ok=True)

stamp = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
#txt_path = logs_dir / f"{slugify(scenario_name)}__{slugify(CONFIG_NAME)}__{stamp}.txt"
txt_path = logs_dir / f"aircraft_maintenance_routing_system__c_min__20260217-140917.txt"
print( txt_path)
# Out:
# logs/aircraft_maintenance_routing_system__c_min__20260217-140917.txt

# %%
"""with txt_path.open("w", encoding="utf-8") as f:
    f.write("EXPERIMENT LOG\n")
    f.write("=" * 70 + "\n")
    f.write(f"SCENARIO: {scenario_name}\n")

    f.write(f"CONFIG: {CONFIG_NAME}\n")
    f.write(f"MODEL: {MODEL}\n")
    f.write(f"TEMPERATURE: {TEMPERATURE}\n")
    f.write(f"CREATED_AT: {stamp}\n")
    f.write("=" * 70 + "\n\n")"""
# Out:
# 'with txt_path.open("w", encoding="utf-8") as f:\n    f.write("EXPERIMENT LOG\n")\n    f.write("=" * 70 + "\n")\n    f.write(f"SCENARIO: {scenario_name}\n")\n\n    f.write(f"CONFIG: {CONFIG_NAME}\n")\n    f.write(f"MODEL: {MODEL}\n")\n    f.write(f"TEMPERATURE: {TEMPERATURE}\n")\n    f.write(f"CREATED_AT: {stamp}\n")\n    f.write("=" * 70 + "\n\n")'

# %%
def dict_to_bullets(d, indent: int = 4) -> str:
   
    pad = " " * indent
    lines = []

    if d is None or d == {}:
        return f"{pad}- (none)"

    def walk(node, level: int, show_key: bool = True):
        pad2 = " " * level

        if isinstance(node, dict):
            if not node:
                lines.append(f"{pad2}- (none)")
                return
            for k, v in node.items():
                # Skip printing the first-level key labels
                if show_key:
                    key = str(k) if k is not None and str(k).strip() else "(unnamed)"
                    lines.append(f"{pad2}- {key}:")
                    walk(v, level + 2, show_key=True)
                else:
                    # First level: don't print key, just descend into its value
                    walk(v, level, show_key=True)

        elif isinstance(node, (list, tuple, set)):
            node = list(node)
            if not node:
                lines.append(f"{pad2}- (none)")
            else:
                for item in node:
                    if isinstance(item, (dict, list, tuple, set)):
                        lines.append(f"{pad2}-")
                        walk(item, level + 2, show_key=True)
                    else:
                        lines.append(f"{pad2}- {item}")

        else:
            val = str(node).strip()
            lines.append(f"{pad2}- {val if val else '(empty)'}")

    # Start at root with show_key=False so first-level keys are hidden
    walk(d, indent, show_key=False)
    return "\n".join(lines)

# %%
iteration_id=1

# %%
from openai import OpenAI

client = OpenAI(base_url="http://127.0.0.1:8000/v1", api_key="local-dummy")

def generate_completion(
    scenario_name: str,
    elements: dict,
    model: str,
     dsl: str, 
    temperature: float = 0.0,
    n_additions: int = 3,
  
   
) -> tuple[str, str]:
    

    # Build partial model text from elements
    elems_block =  dict_to_bullets(elements, indent=4)
    
    partial_model = f"""Elements: \n {elems_block}"""

    prompt = f"""
            You are a modeling assistant. Complete a partial {dsl} for the scenario.

            Scenario: {scenario_name}
            Current partial model:
            {partial_model}

            

            Task:
            Propose up to {n_additions} additions to extend the model.
            You decide which type(s) to add based on what is missing or most impactful for completeness and consistency.
            Avoid duplicates; prefer additions that attach to existing elements. precise the type of the concept you suggest 

            Output:
            Bullet list only, one addition per bullet, concise.
            """.strip()

    resp = client.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=temperature,
        max_tokens=400,  
    )

    output_text = resp.choices[0].message.content
    return prompt, output_text

# %% [markdown]
# I AM HERE  after adding a metric

# %%
iteration_id= 23

# %%
iteration_id += 1

prompt, output_text = generate_completion(
    scenario_name=scenario_name,
    elements={
        "arch": [ 
            {"process": ["maintenance_forecasting", "maintenance_scheduling", "aircraft_routing_optimization"," spare_parts_allocation", "maintenance_execution", "slot_reservation", "shipment planning"]},
            {"Resource" :["aircraft","maintenance_crew", "maintenance_hangar","spare_parts"]},
            {"entity": ["distribution center","airport"]},
              {"Metric": "parts availability rate"}
            
        ],

        "connections": [
            
            {"information_flow": ["maintenance_forecasting - maintenance_scheduling", 
                                  "maintenance_scheduling - aircraft_routing_optimization", 
                                  "aircraft_routing_optimization - slot_reservation", 
                                  "shipment planning - maintenance_execution"]},
           {"uses": ["spare_parts_allocation - spare_parts", "maintenance_execution - maintenance_crew ", "aircraft_routing_optimization - aircraft"]},
                   {"applies_to": ["maintenance execution - maintenance deadline", "maintenance execution - capacity limit"]}

        ],
        "characteristics": [ 
                        {"Constraint": ["maintenance deadline", "capacity limit "]}

            ]
    }


,
    model=MODEL,
    temperature=TEMPERATURE,
    n_additions=3,
    dsl="supply chain management (SCM) modeling language",

)
print("type(output_text) =", type(output_text))
print("preview(repr) =", repr(output_text)[:300])

print("===== PROMPT =====")
print(prompt)
print("\n===== MODEL OUTPUT =====")
print(output_text)
# Out:
# type(output_text) = <class 'str'>
# preview(repr) = '* Entity: **Vendor**, to represent external suppliers of spare parts, attaching to the existing spare_parts resource and spare_parts_allocation process.\n* Metric: **Maintenance Cycle Time**, to measure the time taken for maintenance execution, applying to the maintenance_execution process and infl
# ===== PROMPT =====
# You are a modeling assistant. Complete a partial supply chain management (SCM) modeling language for the scenario.
#
#             Scenario: Aircraft maintenance routing system
#             Current partial model:
#             Elements:
#      -
#       - process:
#         - maintenance_forecasting
#         - maintenance_scheduling
#         - aircraft_routing_optimization
#         -  spare_parts_allocation
#         - maintenance_execution
#         - slot_reservation
#         - shipment planning
#     -
#       - Resource:
#         - aircraft
#         - maintenance_crew
#         - maintenance_hangar
#         - spare_parts
#     -
#       - entity:
#         - distribution center
#         - airport
#     -
#       - Metric:
#         - parts availability rate
#     -
#       - information_flow:
#         - maintenance_forecasting - maintenance_scheduling
#         - maintenance_scheduling - aircraft_routing_optimization
#         - aircraft_routing_optimization - slot_reservation
#         - shipment planning - maintenance_execution
#     -
#       - uses:
#         - spare_parts_allocation - spare_parts
#         - maintenance_execution - maintenance_crew
#         - aircraft_routing_optimization - aircraft
#     -
#       - applies_to:
#         - maintenance execution - maintenance deadline
#         - maintenance execution - capacity limit
#     -
#       - Constraint:
#         - maintenance deadline
#         - capacity limit
#
#
#
#             Task:
#             Propose up to 3 additions to extend the model.
#             You decide which type(s) to add based on what is missing or most impactful for completeness and consistency.
#             Avoid duplicates; prefer additions that attach to existing elements. precise the type of the concept you suggest
#
#             Output:
#             Bullet list only, one addition per bullet, concise.
#
# ===== MODEL OUTPUT =====
# * Entity: **Vendor**, to represent external suppliers of spare parts, attaching to the existing spare_parts resource and spare_parts_allocation process.
# * Metric: **Maintenance Cycle Time**, to measure the time taken for maintenance execution, applying to the maintenance_execution process and influenced by the maintenance_crew and maintenance_hangar resources.
# * Constraint: **Spare Parts Lead Time**, to represent the time it takes for spare parts to be delivered from vendors or distribution centers, affecting the spare_parts_allocation process and shipment planning information flow.

# %%
# ===== Manually fill this dict (we copy/paste items from output) =====
classified = {
    "arch": [
    
    {"entity": ["supplier"], 
     }


    ],
    "connections": [
        {"information_flow": ["maintenance_execution - maintenance_forecasting"]}
    ],
    "characteristics": [
                  {"Constraint": "aircraft availability"}
    ],
}

# ===== Log everything (prompt + output + youand the  manual dict we accepted to integrate) =====
with txt_path.open("a", encoding="utf-8") as f:
    f.write(f"\n\nITERATION {iteration_id}\n")
    f.write("-" * 80 + "\n")


    f.write("PROMPT\n")
    f.write("-" * 80 + "\n")
    f.write(prompt + "\n\n")

    f.write("MODEL OUTPUT\n")
    f.write("-" * 80 + "\n")
    f.write(output_text.strip() + "\n\n")

    f.write("MANUAL CLASSIFICATION\n")
    f.write("-" * 80 + "\n")
    f.write("ARCH:\n")
    for x in classified["arch"]:
        f.write(f"- {x}\n")
    f.write("\nCONNECTIONS:\n")
    for x in classified["connections"]:
        f.write(f"- {x}\n")
    f.write("\nCHARACTERISTICS:\n")
    for x in classified["characteristics"]:
        f.write(f"- {x}\n")

print(f"\nLogged iteration {iteration_id} to:", txt_path)
classified
# Out:
# Logged iteration 23 to: logs/aircraft_maintenance_routing_system__c_min__20260217-140917.txt
# {'arch': [{'entity': ['supplier']}],
#  'connections': [{'information_flow': ['maintenance_execution - maintenance_forecasting']}],
#  'characteristics': [{'Constraint': 'aircraft availability'}]}

# %%
# ===== Manually fill accepted items for this iteration =====
accepted = {
    "arch": [
     

    ],
    "connections": [

        ],
    "characteristics": [
    ],
}

# ===== Append accepted to the same log file =====
with txt_path.open("a", encoding="utf-8") as f:
    f.write("\n\nACCEPTED (ITERATION {})\n".format(iteration_id))
    f.write("-" * 80 + "\n")

    f.write("ARCH:\n")
    for x in accepted["arch"]:
        f.write(f"- {x}\n")

    f.write("\nCONNECTIONS:\n")
    for x in accepted["connections"]:
        f.write(f"- {x}\n")

    f.write("\nCHARACTERISTICS:\n")
    for x in accepted["characteristics"]:
        f.write(f"- {x}\n")

print(f"Accepted suggestions appended for iteration {iteration_id} to:", txt_path)
accepted
# Out:
# Accepted suggestions appended for iteration 23 to: logs/aircraft_maintenance_routing_system__c_min__20260217-140917.txt
# {'arch': [], 'connections': [], 'characteristics': []}

# %%
added_elements ={
    "arch": [
            {"Metric": "parts availability rate"}
    ],
    "connections": [  
    ],
    "characteristics": [
    
    ]
      
}
# ===== Append new added line  to the same log file =====
with txt_path.open("a", encoding="utf-8") as f:
    f.write("\n\nADDED ELEMENTS MANUALLY (ITERATION {})\n".format(iteration_id))
    f.write("-" * 80 + "\n")

    f.write("ARCH:\n")
    for x in added_elements["arch"]:
        f.write(f"- {x}\n")

    f.write("\nCONNECTIONS:\n")
    for x in added_elements["connections"]:
        f.write(f"- {x}\n")

    f.write("\nCHARACTERISTICS:\n")
    for x in added_elements["characteristics"]:
        f.write(f"- {x}\n")
